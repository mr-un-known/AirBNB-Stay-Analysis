# %% [markdown]
# # Importing necessary modules

# %%
import pandas as pd

# %% [markdown]
# # Reading the dataset

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %% [markdown]
# # Location - wise filtering

# %%
def location_filter(loc_name):
    return df.loc[df['neighbourhood_group'].str.contains(loc_name, case=False, regex=False)]

# %%
loc_df = location_filter(input("Enter required location: "))
loc_df
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#            host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 1           Jennifer           Manhattan         Midtown  40.75362  -73.98377
# 2          Elisabeth           Manhattan          Harlem  40.80902  -73.94190
# 4              Laura           Manhattan     East Harlem  40.79851  -73.94399
# 5              Chris           Manhattan     Murray Hill  40.74767  -73.97500
# 7           Shunichi           Manhattan  Hell's Kitchen  40.76489  -73.98493
# ...              ...                 ...             ...       ...        ...
# 48886          Scott           Manhattan         Midtown  40.75561  -73.96723
# 48888            Kat           Manhattan  Hell's Kitchen  40.76392  -73.99183
# 48892  Ilgar & Aysel           Manhattan          Harlem  40.81475  -73.94867
# 48893            Taz           Manhattan  Hell's Kitchen  40.75751  -73.99112
# 48894     Christophe           Manhattan  Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 1      Entire home/apt    225               1                 45  2019-05-21
# 2         Private room    150               3                  0         NaN
# 4      Entire home/apt     80              10                  9  2018-11-19
# 5      Entire home/apt    200               3                 74  2019-06-22
# 7         Private room     79               2                430  2019-06-24
# ...                ...    ...             ...                ...         ...
# 48886  Entire home/apt    200               6                  0         NaN
# 48888     Private room    125               4                  0         NaN
# 48892  Entire home/apt    115              10                  0         NaN
# 48893      Shared room     55               1                  0         NaN
# 48894     Private room     90               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1                   0.38                               2               355
# 2                    NaN                               1               365
# 4                   0.10                               1                 0
# 5                   0.59                               1               129
# 7                   3.47                               1               220
# ...                  ...                             ...               ...
# 48886                NaN                               1               176
# 48888                NaN                               1                31
# 48892                NaN                               1                27
# 48893                NaN                               6                 2
# 48894                NaN                               1                23
#
# [21661 rows x 16 columns]

# %% [markdown]
# # Room - wise filtering

# %%
def room_filter(room):
    return loc_df.loc[df['room_type'] == room.capitalize()]

# %%
room_df = room_filter(input("Enter required room type: "))
room_df
# Out:
#              id                                               name    host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 11         5441                    Central Manhattan/near Broadway       7989
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# ...         ...                                                ...        ...
# 48876  36478357    Cozy, Air-Conditioned Private Bedroom in Harlem  177932088
# 48883  36482416       Sunny Bedroom NYC! Walking to Central Park!!  131529729
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#         host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 2       Elisabeth           Manhattan           Harlem  40.80902  -73.94190
# 7        Shunichi           Manhattan   Hell's Kitchen  40.76489  -73.98493
# 8       MaryEllen           Manhattan  Upper West Side  40.80178  -73.96723
# 11           Kate           Manhattan   Hell's Kitchen  40.76076  -73.98867
# 13        Claudio           Manhattan  Upper West Side  40.79826  -73.96113
# ...           ...                 ...              ...       ...        ...
# 48876      Joseph           Manhattan           Harlem  40.80953  -73.95410
# 48883     Kendall           Manhattan      East Harlem  40.79755  -73.93614
# 48885     Kendall           Manhattan      East Harlem  40.79633  -73.93605
# 48888         Kat           Manhattan   Hell's Kitchen  40.76392  -73.99183
# 48894  Christophe           Manhattan   Hell's Kitchen  40.76404  -73.98933
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 2      Private room    150               3                  0         NaN
# 7      Private room     79               2                430  2019-06-24
# 8      Private room     79               2                118  2017-07-21
# 11     Private room     85               2                188  2019-06-23
# 13     Private room     85               2                113  2019-07-05
# ...             ...    ...             ...                ...         ...
# 48876  Private room     60               1                  0         NaN
# 48883  Private room     75               2                  0         NaN
# 48885  Private room     75               2                  0         NaN
# 48888  Private room    125               4                  0         NaN
# 48894  Private room     90               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 2                    NaN                               1               365
# 7                   3.47                               1               220
# 8                   0.99                               1                 0
# 11                  1.50                               1                39
# 13                  0.91                               1               333
# ...                  ...                             ...               ...
# 48876                NaN                               1                26
# 48883                NaN                               2               364
# 48885                NaN                               2               353
# 48888                NaN                               1                31
# 48894                NaN                               1                23
#
# [7982 rows x 16 columns]

# %% [markdown]
# # Price - wise filtering

# %%
def price(max_price, min_price):
    price_df = room_df.loc[(df['price'] <= max_price) & (df['price'] >= min_price)]
    return price_df.sort_values(by = 'price')

# %%
price_df = price(int(input("Enter maximum price: ")), int(input("Enter minimum price: ")))
price_df
# Out:
#              id                                               name    host_id  \
# 37024  29435528    Single cozy room in Manhattan's Upper West Side   39481825
# 17955  14066702                           Room in Uptown Manhattan   84463909
# 6720    4824211                  Bright Comfy Room in East Village   24841295
# 18061  14141215                                private room in LES   85368273
# 42566  33043051                 Cosy private bedroom in UES/Harlem   41348157
# ...         ...                                                ...        ...
# 38488  30289305                    New York Getaway Beautiful Room  212263525
# 38505  30295881                           Cozy Chinatown Apartment   31358380
# 24022  19364229    Heart of Chelsea Private room in a serviced 2BD    4048704
# 12072   9387120                Private Room/Full Bed, East Village   48695642
# 24143  19452119  Huge Modern Room in a Large Apartment - Manhattan   90531014
#
#            host_name neighbourhood_group        neighbourhood  latitude  \
# 37024            Ami           Manhattan  Morningside Heights  40.80559
# 17955         Sandra           Manhattan   Washington Heights  40.83850
# 6720       Micheline           Manhattan         East Village  40.72503
# 18061            Nir           Manhattan      Lower East Side  40.71795
# 42566          Petra           Manhattan          East Harlem  40.79342
# ...              ...                 ...                  ...       ...
# 38488  SamariSankofa           Manhattan               Harlem  40.81051
# 38505          Keith           Manhattan            Chinatown  40.71700
# 24022           Tala           Manhattan              Chelsea  40.74170
# 12072           Anne           Manhattan         East Village  40.72314
# 24143        Nabeela           Manhattan          East Harlem  40.78565
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 37024  -73.96606  Private room     70               1                 15
# 17955  -73.94313  Private room     70               3                 15
# 6720   -73.97696  Private room     70               2                  5
# 18061  -73.98553  Private room     70               1                  1
# 42566  -73.93889  Private room     70               2                  3
# ...          ...           ...    ...             ...                ...
# 38488  -73.94014  Private room    100               1                  8
# 38505  -73.99717  Private room    100               3                  1
# 24022  -74.00229  Private room    100               3                  1
# 12072  -73.98066  Private room    100               1                  1
# 24143  -73.94360  Private room    100               2                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 37024  2019-07-02               1.77                               1
# 17955  2017-05-02               0.43                               1
# 6720   2017-06-08               0.14                               1
# 18061  2016-10-03               0.03                               1
# 42566  2019-03-30               0.84                               3
# ...           ...                ...                             ...
# 38488  2019-06-03               1.26                               3
# 38505  2018-11-26               0.13                               1
# 24022  2017-07-15               0.04                               1
# 12072  2015-12-01               0.02                               1
# 24143  2019-01-01               0.42                               1
#
#        availability_365
# 37024                16
# 17955                95
# 6720                  0
# 18061                 0
# 42566                10
# ...                 ...
# 38488               253
# 38505                88
# 24022                 0
# 12072                 0
# 24143                66
#
# [3224 rows x 16 columns]

# %% [markdown]
# # Sorting existing dataset by number of reviews
# (Highest to Lowest)

# %%
def review_filter():
    sort_by_review_df = price_df.sort_values(by = 'number_of_reviews', ascending = False)
    return sort_by_review_df

# %%
review_filter()
# Out:
#              id                                              name    host_id  \
# 1879     834190          Manhattan Lux Loft.Like.Love.Lots.Look !    2369681
# 1190     506121                  Cozy Room in Lively East Village    2267153
# 1125     476983               PRIVATE Room in Spacious, Quiet Apt     277379
# 7          5178                  Large Furnished Room Near B'way        8967
# 2092     945297                East Village Gay Friendly Dbl Room    5074654
# ...         ...                                               ...        ...
# 12462   9593093                  Beautiful Spacious Apt In Harlem   49651648
# 25204  20176191         Enormous Private Room in Shared Apartment    6971106
# 26422  21031177    My Cozy Condo!\nMy apartment is very peaceful!  150665890
# 44981  34486925  Nobel Expereices -  Central Park & Carnegie Hall  261761196
# 24992  20016469                           Quaint Nolita Apartment   45374780
#
#           host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 1879          Carol           Manhattan  Lower East Side  40.71921  -73.99116
# 1190           John           Manhattan     East Village  40.72760  -73.98347
# 1125          Agnes           Manhattan           Harlem  40.82537  -73.94392
# 7          Shunichi           Manhattan   Hell's Kitchen  40.76489  -73.98493
# 2092           Seth           Manhattan     East Village  40.72836  -73.98163
# ...             ...                 ...              ...       ...        ...
# 12462        Morgan           Manhattan           Harlem  40.80196  -73.95261
# 25204       Michael           Manhattan  Upper West Side  40.79938  -73.97057
# 26422          Edna           Manhattan     East Village  40.72484  -73.97460
# 44981  Park Central           Manhattan          Midtown  40.76581  -73.98350
# 24992           Zal           Manhattan     Little Italy  40.72008  -73.99612
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 1879   Private room     99               2                540  2019-07-06
# 1190   Private room     72               5                451  2019-06-30
# 1125   Private room     85               1                439  2019-07-05
# 7      Private room     79               2                430  2019-06-24
# 2092   Private room    100               1                414  2019-06-22
# ...             ...    ...             ...                ...         ...
# 12462  Private room     75               1                  0         NaN
# 25204  Private room    100               5                  0         NaN
# 26422  Private room    100               2                  0         NaN
# 44981  Private room    100               1                  0         NaN
# 24992  Private room     95               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 1879                6.95                               1               179
# 1190                5.26                               2                13
# 1125                5.12                               2               238
# 7                   3.47                               1               220
# 2092                5.39                               2               231
# ...                  ...                             ...               ...
# 12462                NaN                               1                 0
# 25204                NaN                               2                 0
# 26422                NaN                               1                99
# 44981                NaN                               8               309
# 24992                NaN                               1                 0
#
# [3224 rows x 16 columns]
